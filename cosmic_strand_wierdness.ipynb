# %%
""" why does the cosmic encode the wrong REF bases for some of these loci?? """

# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
cosmic = pd.read_csv('/Users/lincoln.harris/code/SNP_calling_pipeline/getMutationCounts/CosmicGenomeScreensMutantExport.tsv', sep = '\t')
cosmic
# Out:
#                         Gene name Accession Number  Gene CDS length HGNC ID  \
# 0                            TRIO  ENST00000344204             9294   12303
# 1           ABCC4_ENST00000376887  ENST00000376887             3978     NaN
# 2            TP53_ENST00000413465  ENST00000413465              858   11998
# 3                            EXD3  ENST00000340951             2274   26023
# 4                           ELMO2  ENST00000396391             2163   17233
# 5        C6orf165_ENST00000369562  ENST00000369562             1869     NaN
# 6                            LYST  ENST00000389793            11406    1968
# 7            TP53_ENST00000269305  ENST00000269305             1182     NaN
# 8                         APBB1IP  ENST00000376236             2001   17379
# 9            MKS1_ENST00000337050  ENST00000337050             1566    7121
# 10                           ACO1  ENST00000309951             2670     117
# ...

# %%
# subset
keep = cosmic['Gene name'] == 'KRAS'
sub = cosmic[keep]
keep1 = cosmic['Primary site'] == 'lung'
sub1 = sub[keep1]
cosmic_goi_sub = sub1
cosmic_goi_sub
# Out:
# /Users/lincoln.harris/anaconda3/envs/cerebra/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
#         Gene name Accession Number  Gene CDS length HGNC ID  \
# 59294        KRAS  ENST00000311936              567    6407
# 61601        KRAS  ENST00000311936              567    6407
# 92246        KRAS  ENST00000311936              567    6407
# 102864       KRAS  ENST00000311936              567    6407
# 152135       KRAS  ENST00000311936              567    6407
# 170204       KRAS  ENST00000311936              567    6407
# 189371       KRAS  ENST00000311936              567    6407
# 213338       KRAS  ENST00000311936              567    6407
# 248703       KRAS  ENST00000311936              567    6407
# 269827       KRAS  ENST00000311936              567    6407
# 321424       KRAS  ENST00000311936              567    6407
# 388959       KRAS  ENST00000311936              567    6407
# ...

# %%
keep = cosmic_goi_sub['Mutation AA'] == 'p.V600E'
cosmic_goi_sub[keep]
# Out:
#         Gene name Accession Number  Gene CDS length HGNC ID      Sample name  \
# 1451618      BRAF  ENST00000288602             2301    1097  TCGA-80-5607-01
# 2580496      BRAF  ENST00000288602             2301    1097  TCGA-55-7903-01
# 3296094      BRAF  ENST00000288602             2301    1097           LC_S41
# 3819227      BRAF  ENST00000288602             2301    1097  TCGA-44-2666-01
# 4465368      BRAF  ENST00000288602             2301    1097  TCGA-50-5942-01
# 5223445      BRAF  ENST00000288602             2301    1097     LUAD-NYU1096
# 5231534      BRAF  ENST00000288602             2301    1097  TCGA-86-7714-01
#
#          ID_sample  ID_tumour Primary site    Site subtype 1 Site subtype 2  \
# 1451618    1914078    1802360         lung  right_upper_lobe             NS
# 2580496    1914027    1802309         lung  right_lower_lobe             NS
# 3296094    1863752    1754643         lung                NS             NS
# ...

# %%
row = cosmic_goi_sub.iloc[0]
row['Mutation strand']
# Out:
# '-'
