# %%
# how many 'LUNG' genes in COSMIC?

# %%
import pandas as pd
pd.set_option('display.max_rows', 999)
pd.options.display.max_columns = None

# %%
path = '/Users/lincoln.harris/code/SNP_calling_pipeline/mutationCountsTable/CosmicGenomeScreensMutantExport.tsv'
cosmic = pd.read_csv(path, sep='\t')
cosmic
# Out:
#                          Gene name      Accession Number  Gene CDS length  \
# 0                             TRIO       ENST00000344204             9294
# 1            ABCC4_ENST00000376887       ENST00000376887             3978
# 2             TP53_ENST00000413465       ENST00000413465              858
# 3                             EXD3       ENST00000340951             2274
# 4                            ELMO2       ENST00000396391             2163
# 5         C6orf165_ENST00000369562       ENST00000369562             1869
# 6                             LYST       ENST00000389793            11406
# 7             TP53_ENST00000269305       ENST00000269305             1182
# 8                          APBB1IP       ENST00000376236             2001
# 9             MKS1_ENST00000337050       ENST00000337050             1566
# 10                            ACO1       ENST00000309951             2670
# 11             DST_ENST00000370765       ENST00000370765             7950
# ...

# %%
toKeep = cosmic['Primary site'] == 'lung'
cosmic_lung = cosmic[toKeep]
cosmic_lung
# Out:
#                        Gene name     Accession Number  Gene CDS length  \
# 6                           LYST      ENST00000389793            11406
# 18                           BTK      ENST00000308731             1980
# 20                         PRDM9      ENST00000296682             2685
# 21                          LRP1      ENST00000243077            13635
# 22                         SPTA1      ENST00000368148             7260
# 23          MLL3_ENST00000355193      ENST00000355193            14907
# 24                        ABCA13      ENST00000319379            15012
# 25                        CAMKK2      ENST00000324774             1767
# 26                       FAM75D4      ENST00000344803             4731
# 27                       PIK3AP1      ENST00000339364             2418
# 32                         PTPRB          NM_002837.2             5994
# 34                          GGT1      ENST00000400380             1710
# ...

# %%
unique_genes = set(cosmic_lung['Gene name'])
unique_genes
# Out:
# {'TNFRSF11A',
#  'KDM3B',
#  'C2orf63',
#  'ECHDC3',
#  'C10orf95',
#  'CD244_ENST00000368033',
#  'SAR1A_ENST00000373236',
#  'OR2J3',
#  'ASMTL',
#  'EXOSC5',
#  'PHLPP1',
#  'TAF4B',
#  'DCTN5',
#  'PPIP5K1_ENST00000348806',
#  'ADCK3_ENST00000366779',
#  'GMPR2_ENST00000348719',
#  'COG6_ENST00000416691',
#  'TTC9B',
#  'TCF4_ENST00000564403',
#  'PNPLA7',
#  'ERI3_ENST00000372259',
#  'C20orf94',
#  'TEF',
#  'POF1B',
#  'KATNAL2',
#  'DBNL_ENST00000468694',
#  'UBE2L6',
#  'FYTTD1',
#  'GADD45B',
#  'LSM14A_ENST00000433627',
#  'ERI1',
#  'SETD6',
#  'ZNF431',
#  'NPR2',
#  'CAMK2G_ENST00000322635',
#  'NANOGNB',
#  'SERPINA6',
#  'ASB18_ENST00000409749',
#  'TAC4',
#  'KCNH3',
#  'OSBPL1A',
#  'DLG1',
#  'NUDT5',
#  'FOXO1',
#  'GPC4',
#  'FRMD4A',
#  'SLC39A13_ENST00000362021',
#  'PRKCG',
#  'FLJ25006',
#  'SLC35B1_ENST00000415270',
#  'HSPB1',
#  'SCLT1_ENST00000281142',
#  'SH3GLB2_ENST00000372554',
#  'LRRC70',
#  'Q9BSM8_HUMAN',
#  'LOC389904',
#  'UBE2W',
#  'NECAP2',
# ...

# %%
len(unique_genes)
# Out:
# 27828
