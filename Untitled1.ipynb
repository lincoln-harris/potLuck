# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
pd.read_csv('/Users/lincoln.harris/Desktop/top_panel_muts_by_sample_v1.csv')
# Out:
#              LT_S11       LT_S21      LT_S75       LT_S66           LT_S69  \
# 0        EGFR R521K   EGFR R521K  EGFR N158N   EGFR T903T       EGFR Q787Q
# 1   EGFR K745_A750T   EGFR Q787Q  EGFR Q787Q   EGFR N158N       EGFR T903T
# 2        EGFR T629T   EGFR T903T  EGFR T903T   EGFR R521K       EGFR T629T
# 3        EGFR T903T   EGFR T629T  EGFR L387M   EGFR T629T      EGFR I1093M
# 4        EGFR L833V   EGFR L858R   KRAS Q61H   EGFR Q787Q       EGFR S921R
# 5         KRAS G13V   EGFR A237V         NaN  EGFR V1142V      EGFR L1034I
# 6        BRAF W450L   EGFR A237Y         NaN    EGFR G42D  EGFR K745_A750T
# 7        BRAF G643G   EGFR V536M         NaN   EGFR F856L      EGFR R1052I
# 8               NaN    EGFR G42D         NaN  EGFR D1014N       EGFR S811F
# 9               NaN   EGFR G598V         NaN  EGFR L1167V        KRAS L19F
# 10              NaN  EGFR R1052I         NaN   KRAS C185S        KRAS A11A
# ...

# %%
pd.read_csv('/Users/lincoln.harris/Desktop/total_counts_by_sample.csv')
# Out:
#     sample  EGFR_R521K  EGFR_E746_A750delELREA  KRAS_G12C  EGFR_K745_A750T  \
# 0   LT_S48           0                       0          0                0
# 1   LT_S66         246                       0          0                0
# 2   LT_S56           0                       0          0                0
# 3   LT_S21        1937                      12         30                5
# 4   LT_S07          54                       0          0                0
# 5   LT_S53           0                       0          0                0
# 6   LT_S71           0                       0          0              405
# 7   LT_S55           5                       0          0                0
# 8   LT_S45           0                       0          0                0
# 9   LT_S49           0                       0          0                0
# 10  LT_S54           0                       0          0                0
# ...

# %%
pd.read_csv('/Users/lincoln.harris/Desktop/variant_counts_by_sample.csv')
# Out:
#     sample  EGFR_R521K  EGFR_E746_A750delELREA  KRAS_G12C  EGFR_K745_A750T  \
# 0   LT_S48           0                       0          0                0
# 1   LT_S66         157                       0          0                0
# 2   LT_S56           0                       0          0                0
# 3   LT_S21        1937                       4          8                2
# 4   LT_S07          54                       0          0                0
# 5   LT_S53           0                       0          0                0
# 6   LT_S71           0                       0          0              373
# 7   LT_S55           5                       0          0                0
# 8   LT_S45           0                       0          0                0
# 9   LT_S49           0                       0          0                0
# 10  LT_S54           0                       0          0                0
# ...
